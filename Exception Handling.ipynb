# %%
try:
  x=int(input("Enter a number:"))
  print("You Entered:",x)
except ValueError:
  print("The input is Invalid")
# Out:
# Enter a number:Bhavya
# The input is Invalid

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. ")
# Out:
# Enter a number to divide 100: 0
# Cannot divide by zero!
# Execution complete.

# %%
try:
  num=int("ten")
  b=10/0
except (ValueError,ZeroDivisionError) as e:
  print("Error Occured",e)
# Out:
# Error Occured invalid literal for int() with base 10: 'ten'

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")
    return a / b

print(divide(10, 2))
# Out:
# Dividing 10 by 2
# 5.0

# %%
import traceback
try:
  result=10/0
except Exception as e:
  print("Something went wrong")
  traceback.print_exc()
# Out:
# Something went wrong
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1150/3755438966.py", line 3, in <cell line: 0>
#     result=10/0
#            ~~^~
# ZeroDivisionError: division by zero

# %%
def calculate_total(price, quantity):
    return price * quantity

print(calculate_total(50, 2))
# Out:
# 100

# %%
import random
import datetime
Device_types={
    'Temperature_sensor','Humidity_sensor','Pressure_Sensor','Light-_sensor'
}
Locations={
    'Building1','Building2','Building3','warehouse','Loboratory'
}
READING_RANGES = {
    'Temperature_Sensor': (15.0, 40.0),
    'Humidity_Sensor': (20.0, 90.0),
    'Pressure_Sensor': (950.0, 1050.0),
    'Light_Sensor': (100.0, 1000.0)
}
raw_sensor_data=[]
start_time=datetime.datetime.now()
for i in range(100):


    timestamp = start_time + datetime.timedelta(minutes=i)
    timestamp_str = timestamp.strftime("%Y-%m-%d %H:%M:%S")


    device_number = str(i + 1).zfill(3)
    device_id = "DEV" + device_number


    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)


    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)


    reading = (
        timestamp_str,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)
    for reading in raw_sensor_data[:10]:
      print(reading)

print("\nTotal sensor readings:", len(raw_sensor_data))
# Out:
# ('2026-07-20 09:03:20', 'DEV001', 'Light_Sensor', 'OfficeA', 167.76)
# ('2026-07-20 09:03:20', 'DEV001', 'Light_Sensor', 'OfficeA', 167.76)
# ('2026-07-20 09:04:20', 'DEV002', 'Humidity_Sensor', 'OfficeB', 42.43)
# ('2026-07-20 09:03:20', 'DEV001', 'Light_Sensor', 'OfficeA', 167.76)
# ('2026-07-20 09:04:20', 'DEV002', 'Humidity_Sensor', 'OfficeB', 42.43)
# ('2026-07-20 09:05:20', 'DEV003', 'Humidity_Sensor', 'OfficeA', 58.01)
# ('2026-07-20 09:03:20', 'DEV001', 'Light_Sensor', 'OfficeA', 167.76)
# ('2026-07-20 09:04:20', 'DEV002', 'Humidity_Sensor', 'OfficeB', 42.43)
# ('2026-07-20 09:05:20', 'DEV003', 'Humidity_Sensor', 'OfficeA', 58.01)
# ('2026-07-20 09:06:20', 'DEV004', 'Pressure_Sensor', 'Lab2', 965.4)
# ('2026-07-20 09:03:20', 'DEV001', 'Light_Sensor', 'OfficeA', 167.76)
# ('2026-07-20 09:04:20', 'DEV002', 'Humidity_Sensor', 'OfficeB', 42.43)
# ('2026-07-20 09:05:20', 'DEV003', 'Humidity_Sensor', 'OfficeA', 58.01)
# ...

# %%
temperature_readings = []
for reading in raw_sensor_data:

    if reading[2] == "Temperature_Sensor":
        temp_dict = {
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        }


        temperature_readings.append(temp_dict)


for item in temperature_readings[:5]:
    print(item)

print("\nTotal Temperature Readings:", len(temperature_readings))
# Out:
# {'timestamp': '2026-07-20 09:14:20', 'device_id': 'DEV012', 'location': 'OfficeB', 'temperature_celsius': 24.62}
# {'timestamp': '2026-07-20 09:15:20', 'device_id': 'DEV013', 'location': 'OfficeA', 'temperature_celsius': 37.96}
# {'timestamp': '2026-07-20 09:19:20', 'device_id': 'DEV017', 'location': 'Lab2', 'temperature_celsius': 23.07}
# {'timestamp': '2026-07-20 09:24:20', 'device_id': 'DEV022', 'location': 'Lab2', 'temperature_celsius': 31.8}
# {'timestamp': '2026-07-20 09:28:20', 'device_id': 'DEV026', 'location': 'OfficeA', 'temperature_celsius': 23.63}
#
# Total Temperature Readings: 26

# %%
unique_locations = set()


for reading in raw_sensor_data:
    unique_locations.add(reading[3])


print("Unique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'Lab2', 'OfficeB', 'Lab1', 'Warehouse', 'OfficeA'}

# %%
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)


print("Device Statistics:")
for device_type in device_stats:
    print(device_type, ":", device_stats[device_type])
# Out:
# Device Statistics:
# Temperature_Sensor : (16.73, 39.1)
# Humidity_Sensor : (20.72, 86.26)
# Pressure_Sensor : (954.0, 1030.78)
# Light_Sensor : (136.34, 977.38)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")


sample_string = "PythonProgrammingIsFun"

sliced_readings_1 = raw_sensor_data[9:20]


sliced_readings_2 = raw_sensor_data[::5]

print("10th to 20th readings:")
print(sliced_readings_1)

print("\nEvery 5th reading:")
print(sliced_readings_2)


substring_1 = sample_string[6:17]

substring_2 = sample_string[5::-1]

print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)


fifth_reading_device_type = raw_sensor_data[4][2]


device_type_suffix = fifth_reading_device_type[-6:]

print("\nDevice Type of 5th Reading:", fifth_reading_device_type)
print("Suffix:", device_type_suffix)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# 10th to 20th readings:
# [('2026-07-20 09:12:20', 'DEV010', 'Humidity_Sensor', 'OfficeB', 29.07), ('2026-07-20 09:13:20', 'DEV011', 'Light_Sensor', 'OfficeA', 725.77), ('2026-07-20 09:14:20', 'DEV012', 'Temperature_Sensor', 'OfficeB', 24.62), ('2026-07-20 09:15:20', 'DEV013', 'Temperature_Sensor', 'OfficeA', 37.96), ('2026-07-20 09:16:20', 'DEV014', 'Humidity_Sensor', 'Lab1', 80.59), ('2026-07-20 09:17:20', 'DEV015', 'Light_Sensor', 'Lab1', 920.64), ('2026-07-20 09:18:20', 'DEV016', 'Humidity_Sensor', 'OfficeA', 69.81), ('2026-07-20 09:19:20', 'DEV017', 'Temperature_Sensor', 'Lab2', 23.07), ('2026-07-20 09:20:20', 'DEV018', 'Light_Sensor', 'Lab2', 172.84), ('2026-07-20 09:21:20', 'DEV019', 'Humidity_Sensor', 'OfficeB', 86.2), ('2026-07-20 09:22:20', 'DEV020', 'Humidity_Sensor', 'Warehouse', 20.72)]
#
# Every 5th reading:
# ...

# %%
def get_readings_by_location(readings_list, target_location):


    location_readings = []


    for reading in readings_list:


        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings



building_a_readings = get_readings_by_location(raw_sensor_data, "Building_A")

print("Readings from Building_A:")
for reading in building_a_readings:
    print(reading)

print("\nTotal Readings:", len(building_a_readings))
# Out:
# Readings from Building_A:
#
# Total Readings: 0

# %%
def calculate_average_temperature(temp_data_list):


    if len(temp_data_list) == 0:
        return 0.0

    total_temperature = 0


    for reading in temp_data_list:
        total_temperature += reading["temperature_celsius"]


    average_temperature = total_temperature / len(temp_data_list)

    return average_temperature



average = calculate_average_temperature(temperature_readings)

print("Average Temperature:", round(average, 2), "°C")
# Out:
# Average Temperature: 28.94 °C
